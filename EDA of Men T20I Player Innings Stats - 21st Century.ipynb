# %% [markdown]
# PROJECT PROPOSAL
#
# Data Set Name - Men T20I Player Innings Stats - 21st Century
#
# source(download link) - https://www.kaggle.com/cclayford/cricinfo-statsguru-data/download
#
# Source link -  https://www.kaggle.com/cclayford/cricinfo-statsguru-data#Men%20T20I%20Player%20Innings%20Stats%20-%2021st%20Century.csv (this link doesn't work now so i have provided the download link)
#
# I have got this data from the links provided by you(i have discussed my interests with you and you provided me some links).
#
# cost of data - free, it is an open source.
#
# data is legal to access.
#
# I am working with a CSV that isn't analyzed in the existing kernels.
#
# The dataset consists of 69617 rows and 28 columns and has more than two different types of entries(int, float, text,date, etc.)
#
# size - 6.40 MB
#
# I used to play cricket a lot back when I was in my country. So, I taught of taking a dataset based on cricket. The dataset is all about individual player stats of T20I matches.
#
# HYPOTHESIS:
#
# Given individual player stats of T20I matches, I could hypothesize
#
# 1) An individual player(RG Sharma) has highest score in an innings against a particular Nation(Sri Lanka) in his career.
#
# 2) An individual player(V Kohli) has scored most runs in a particular country(India).
#
# 3)  An individual player(RG Sharma) has played most number of matches for a particular country(India).
#
# 4)  G Maxwell has best strike rate in overall T20I matches.
#
# 5)  A Finch has scored highest number of sixes in an innings.
#
# I found the above records in  https://stats.espncricinfo.com/ci/engine/stats/index.html
#
# I came up with these hypothesis from the background knowledge I have in cricket
#
# So, these are testable.

# %% [markdown]
# PRIMARY OBSERVATION
#
# Dataset has individual player batting and bowling stats of each T20I match played by him.

# %%
import os
os.chdir('C:/Users/chand/Downloads')

# %%
pip install missingno

# %%
import pandas as pd
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Men T20I Player Innings Stats - 21st Century.csv')
data.head()
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0       AD Hales                116*                     116
# 1       DJ Malan                103*                     103
# 2      LJ Wright                 99*                      99
# 3       AD Hales                  99                      99
# 4       AD Hales                  94                      94
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                     97                  1.0                   1.0
# 1                     79                  1.0                   1.0
# 2                     83                  1.0                   1.0
# 3                     84                  1.0                   0.0
# 4                     80                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  64                     11                      6
# ...

# %%
data.shape
# Out:
# (69616, 28)

# %%
data[34962:34967]
# Out:
#       Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 34962       AD Hales                116*                     116
# 34963       DJ Malan                103*                     103
# 34964      LJ Wright                 99*                      99
# 34965       AD Hales                  99                      99
# 34966       AD Hales                  94                      94
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 34962                     97                  1.0                   1.0
# 34963                     79                  1.0                   1.0
# 34964                     83                  1.0                   1.0
# 34965                     84                  1.0                   0.0
# 34966                     80                  1.0                   0.0
#
#       Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %% [markdown]
# Here you can observe that there exists duplicate rows.

# %%
#removing Duplicate rows
data.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
data.shape
# Out:
# (34960, 28)

# %%
data.isnull().sum()
# Out:
# Innings Player                       0
# Innings Runs Scored              17479
# Innings Runs Scored Num          17479
# Innings Minutes Batted           17479
# Innings Batted Flag              17479
# Innings Not Out Flag             17479
# Innings Balls Faced              17479
# Innings Boundary Fours           17479
# Innings Boundary Sixes           17479
# Innings Batting Strike Rate      17479
# Innings Number                       0
# Opposition                           0
# Ground                               0
# Innings Date                         0
# Country                              0
# 50's                             17479
# 100's                            17479
# Innings Runs Scored Buckets      17479
# Innings Overs Bowled             17481
# Innings Bowled Flag              17481
# Innings Maidens Bowled           17481
# Innings Runs Conceded            17481
# Innings Wickets Taken            17481
# 4 Wickets                        17481
# ...

# %% [markdown]
# There are many null values.
# so plotting a graph to see where the null values exists.

# %%
msno.matrix(data)

# %% [markdown]
# In the data, rows from 'Innings runs scored' to 'Innings batting strike rate' and 50's, 100's, Innings run scored buckets are batting stats
# And from 'Innings overs bowled' to 'Innings economy rate' are bowling stats.
# Remaining columns are player name and match information.
#
# From the above graph, for batting stats we can see that there are a set of values present when bowling stats are null and then there are a set of null values in batting stats when there are values present in bowling stats.

# %%
multiple_rows = data.loc[(data['Innings Player'] == 'RG Sharma') & (data['Innings Date'] == '2017/12/22')]
multiple_rows
# Out:
#       Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 10794      RG Sharma                 118                     118
# 16293      RG Sharma                 NaN                     NaN
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 10794                     61                  1.0                   0.0
# 16293                    NaN                  NaN                   NaN
#
#       Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 10794                  43                     12                     10
# 16293                 NaN                    NaN                    NaN
#
#       Innings Batting Strike Rate  ... Innings Overs Bowled  \
# 10794                      274.41  ...                  NaN
# 16293                         NaN  ...                  DNB
#
#       Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded  \
# 10794                 NaN                    NaN                   NaN
# ...

# %% [markdown]
# From the above cell output I see that an individual player batting stats and bowling stats of a single
# match are provided in two rows in the dataset. This is throughout the dataset, every player stats of single match are in 2 rows.
#
# That is the reason behind having block of null values in the data.

# %% [markdown]
# All my hypotheses are based on batting stats.
#
# So, I am creating a new dataframe which contains only batting stats that are required to work on my hypotheses.

# %%
data_batting = data[['Innings Player','Innings Runs Scored Num',
       'Innings Minutes Batted', 'Innings Balls Faced', 'Innings Boundary Fours',
       'Innings Boundary Sixes', 'Innings Batting Strike Rate',
       'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
       "50's", "100's"]]
data_batting.head()
# Out:
#   Innings Player Innings Runs Scored Num Innings Minutes Batted  \
# 0       AD Hales                     116                     97
# 1       DJ Malan                     103                     79
# 2      LJ Wright                      99                     83
# 3       AD Hales                      99                     84
# 4       AD Hales                      94                     80
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  64                     11                      6
# 1                  51                      9                      6
# 2                  55                      8                      6
# 3                  68                      6                      4
# 4                  61                     11                      2
#
#   Innings Batting Strike Rate Innings Number     Opposition  \
# 0                      181.25              2    v Sri Lanka
# ...

# %%
data_batting.shape
# Out:
# (34960, 14)

# %%
msno.matrix(data_batting)

# %% [markdown]
# The rows which show null values above are the rows of bowling stats

# %% [markdown]
# So, dropping the rows of null values

# %%
data_batting.dropna(inplace=True)
data_batting.shape
# Out:
# C:\Users\chand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# (17481, 14)

# %%
data_batting
# Out:
#       Innings Player Innings Runs Scored Num Innings Minutes Batted  \
# 0           AD Hales                     116                     97
# 1           DJ Malan                     103                     79
# 2          LJ Wright                      99                     83
# 3           AD Hales                      99                     84
# 4           AD Hales                      94                     80
# ...              ...                     ...                    ...
# 44196  CR Brathwaite                       -                      -
# 55207      AG Cremer                       -                      -
# 60979     Abul Hasan                       -                      -
# 61517        MA Ouma                       -                      -
# 65027      AR Cusack                       -                      -
#
#       Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                      64                     11                      6
# ...

# %%
#msno.matrix(data_batting)
data_batting.isnull().sum()
# Out:
# Innings Player                 0
# Innings Runs Scored Num        0
# Innings Minutes Batted         0
# Innings Balls Faced            0
# Innings Boundary Fours         0
# Innings Boundary Sixes         0
# Innings Batting Strike Rate    0
# Innings Number                 0
# Opposition                     0
# Ground                         0
# Innings Date                   0
# Country                        0
# 50's                           0
# 100's                          0
# dtype: int64

# %% [markdown]
# Now the dataset only contains batting stats
#
# I see a - value in some rows
#
# So, replacing - with null values

# %%
data_batting.replace(r'^-$', np.nan, regex=True, inplace=True)
data_batting
# Out:
# C:\Users\chand\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:4263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
#       Innings Player Innings Runs Scored Num Innings Minutes Batted  \
# 0           AD Hales                     116                     97
# 1           DJ Malan                     103                     79
# 2          LJ Wright                      99                     83
# 3           AD Hales                      99                     84
# 4           AD Hales                      94                     80
# ...              ...                     ...                    ...
# 44196  CR Brathwaite                     NaN                    NaN
# 55207      AG Cremer                     NaN                    NaN
# ...

# %% [markdown]
# issues resolved with the data are:
#
# duplicates are removed
#
# null values are removed from batting stats
#
# '-' values are replaced.

# %% [markdown]
# Data is clean to proceed with my hypotheses.
#
# The characteristics of the data has no change.

# %%
data_batting.dtypes
# Out:
# Innings Player                  object
# Innings Runs Scored Num         object
# Innings Minutes Batted          object
# Innings Balls Faced             object
# Innings Boundary Fours          object
# Innings Boundary Sixes          object
# Innings Batting Strike Rate     object
# Innings Number                  object
# Opposition                      object
# Ground                          object
# Innings Date                    object
# Country                         object
# 50's                           float64
# 100's                          float64
# dtype: object

# %% [markdown]
# type conversion

# %%
data_batting['Innings Runs Scored Num'] = data_batting['Innings Runs Scored Num'].astype(float)
data_batting['Innings Minutes Batted'] = data_batting['Innings Minutes Batted'].astype(float)
data_batting['Innings Balls Faced'] = data_batting['Innings Balls Faced'].astype(float)
data_batting['Innings Boundary Fours'] = data_batting['Innings Boundary Fours'].astype(float)
data_batting['Innings Boundary Sixes'] = data_batting['Innings Boundary Sixes'].astype(float)
data_batting['Innings Batting Strike Rate'] = data_batting['Innings Batting Strike Rate'].astype(float)
# Out:
# C:\Users\chand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\chand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %% [markdown]
# # HYPOTHESIS 1

# %% [markdown]
# An individual player(RG Sharma) has highest score in an innings against a particular Nation(Sri Lanka) in his career.

# %% [markdown]
# Hypothesis is correct

# %%
#creating dataframe which consists only RG Sharma stats
df1 = data_batting[(data_batting['Innings Player'] == 'RG Sharma')]
df1.head()
# Out:
#       Innings Player  Innings Runs Scored Num  Innings Minutes Batted  \
# 10794      RG Sharma                    118.0                    61.0
# 10795      RG Sharma                    111.0                    95.0
# 10797      RG Sharma                    106.0                    79.0
# 10800      RG Sharma                    100.0                     NaN
# 10801      RG Sharma                     97.0                    87.0
#
#        Innings Balls Faced  Innings Boundary Fours  Innings Boundary Sixes  \
# 10794                 43.0                    12.0                    10.0
# 10795                 61.0                     8.0                     7.0
# 10797                 66.0                    12.0                     5.0
# 10800                 56.0                    11.0                     5.0
# 10801                 61.0                     8.0                     5.0
#
#        Innings Batting Strike Rate Innings Number      Opposition  \
# ...

# %%
df1[df1['Innings Runs Scored Num']==df1['Innings Runs Scored Num'].max()]       #returns a row that has max value of 'Innings Runs Scored Num'
# Out:
#       Innings Player  Innings Runs Scored Num  Innings Minutes Batted  \
# 10794      RG Sharma                    118.0                    61.0
#
#        Innings Balls Faced  Innings Boundary Fours  Innings Boundary Sixes  \
# 10794                 43.0                    12.0                    10.0
#
#        Innings Batting Strike Rate Innings Number   Opposition  Ground  \
# 10794                       274.41              1  v Sri Lanka  Indore
#
#       Innings Date Country  50's  100's
# 10794   2017/12/22   India   0.0    1.0

# %% [markdown]
# From the above output RG Sharma has highest score(118) in an innings against Sri Lanka.

# %% [markdown]
# # HYPOTHESIS 2

# %% [markdown]
# An individual player(V Kohli) has scored most runs in a particular country(India).

# %% [markdown]
# Hypothesis is correct

# %%
df2 = data_batting
df2.head()
# Out:
#   Innings Player  Innings Runs Scored Num  Innings Minutes Batted  \
# 0       AD Hales                    116.0                    97.0
# 1       DJ Malan                    103.0                    79.0
# 2      LJ Wright                     99.0                    83.0
# 3       AD Hales                     99.0                    84.0
# 4       AD Hales                     94.0                    80.0
#
#    Innings Balls Faced  Innings Boundary Fours  Innings Boundary Sixes  \
# 0                 64.0                    11.0                     6.0
# 1                 51.0                     9.0                     6.0
# 2                 55.0                     8.0                     6.0
# 3                 68.0                     6.0                     4.0
# 4                 61.0                    11.0                     2.0
#
#    Innings Batting Strike Rate Innings Number     Opposition  \
# 0                       181.25              2    v Sri Lanka
# ...

# %% [markdown]
# Here I need to prove V Kohli has scored most runs in India.
#
# But In the dataset there is no column that describes where(country) the match was held.
#
# Based on the Ground name I need to figure it out.

# %%
df2.Ground.unique()  #getting all the ground names
# Out:
# array(['Chattogram', 'Napier', 'Colombo (RPS)', 'Nottingham',
#        'Chester-le-Street', 'Southampton', 'Basseterre', 'Johannesburg',
#        'Mumbai', 'Wellington', 'Hamilton', 'The Oval', 'Cape Town',
#        'Delhi', 'Cardiff', 'Pallekele', 'Bridgetown', "Lord's",
#        'Birmingham', 'East London', 'Manchester', 'Gros Islet',
#        'Dubai (DSC)', 'Taunton', 'Bristol', 'Hobart', 'Centurion',
#        'Abu Dhabi', 'Christchurch', 'Pune', 'Providence', 'Nelson',
#        'Kolkata', 'Kanpur', 'Durban', 'Auckland', 'Sharjah', 'Melbourne',
#        'Adelaide', 'Bengaluru', 'Nagpur', 'Sydney', 'Port of Spain',
#        'Harare', 'Brisbane', 'Rajkot', 'Perth', 'Canberra', 'Mumbai (BS)',
#        'Dhaka', 'Tolerance Oval', 'Port Elizabeth', 'Guwahati', 'Mohali',
#        'Geelong', 'Visakhapatnam', 'Ranchi', 'Dharamsala', 'Carrara',
#        'Potchefstroom', 'Kimberley', 'Hambantota', 'Bloemfontein',
#        'North Sound', 'Cuttack', 'Kingston', 'Lauderhill', 'Lucknow',
# ...

# %% [markdown]
# replacing all the ground names that are in india with 'In India'

# %%
df2.loc[(df2.Ground == 'Mumbai'),'Ground']='In India'
df2.loc[(df2.Ground == 'Delhi'),'Ground']='In India'
df2.loc[(df2.Ground == 'Pune'),'Ground']='In India'
df2.loc[(df2.Ground == 'Kolkata'),'Ground']='In India'
df2.loc[(df2.Ground == 'Kanpur'),'Ground']='In India'
df2.loc[(df2.Ground == 'Bengaluru'),'Ground']='In India'
df2.loc[(df2.Ground == 'Nagpur'),'Ground']='In India'
df2.loc[(df2.Ground == 'Rajkot'),'Ground']='In India'
df2.loc[(df2.Ground == 'Mumbai (BS)'),'Ground']='In India'
df2.loc[(df2.Ground == 'Guwahati'),'Ground']='In India'
df2.loc[(df2.Ground == 'Mohali'),'Ground']='In India'
df2.loc[(df2.Ground == 'Visakhapatnam'),'Ground']='In India'
df2.loc[(df2.Ground == 'Dharamsala'),'Ground']='In India'
df2.loc[(df2.Ground == 'Cuttack'),'Ground']='In India'
df2.loc[(df2.Ground == 'Lucknow'),'Ground']='In India'
df2.loc[(df2.Ground == 'Thiruvananthapuram'),'Ground']='In India'
df2.loc[(df2.Ground == 'Hyderabad (Deccan)'),'Ground']='In India'
df2.loc[(df2.Ground == 'Chennai'),'Ground']='In India'
df2.loc[(df2.Ground == 'Indore'),'Ground']='In India'
df2.loc[(df2.Ground == 'Ahmedabad'),'Ground']='In India'
df2.loc[(df2.Ground == 'Dehradun'),'Ground']='In India'
df2.loc[(df2.Ground == 'Greater Noida'),'Ground']='In India'
df2.loc[(df2.Ground == 'Ranchi'),'Ground']='In India'

df2.head()
# Out:
# C:\Users\chand\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#   Innings Player  Innings Runs Scored Num  Innings Minutes Batted  \
# 0       AD Hales                    116.0                    97.0
# 1       DJ Malan                    103.0                    79.0
# 2      LJ Wright                     99.0                    83.0
# 3       AD Hales                     99.0                    84.0
# 4       AD Hales                     94.0                    80.0
#
#    Innings Balls Faced  Innings Boundary Fours  Innings Boundary Sixes  \
# 0                 64.0                    11.0                     6.0
# ...

# %% [markdown]
# creating a dataframe that consists only stats of player when played in India

# %%
df_ind = df2.loc[df2['Ground'] == 'In India']
df_ind.head()
# Out:
#    Innings Player  Innings Runs Scored Num  Innings Minutes Batted  \
# 9         JE Root                     83.0                    70.0
# 14         JJ Roy                     78.0                    50.0
# 36     JC Buttler                     66.0                    47.0
# 60       AD Hales                     56.0                    52.0
# 69        JE Root                     54.0                    62.0
#
#     Innings Balls Faced  Innings Boundary Fours  Innings Boundary Sixes  \
# 9                  44.0                     6.0                     4.0
# 14                 44.0                    11.0                     2.0
# 36                 37.0                     8.0                     2.0
# 60                 35.0                     7.0                     2.0
# 69                 36.0                     7.0                     0.0
#
#     Innings Batting Strike Rate Innings Number      Opposition    Ground  \
# ...

# %%
# sum of runs scored by each player
sum = df_ind.groupby('Innings Player')['Innings Runs Scored Num'].sum()

# %%
#top 5 run scorers
sum.nlargest(5)
# Out:
# Innings Player
# V Kohli      1120.0
# RG Sharma     928.0
# KL Rahul      749.0
# S Dhawan      702.0
# MS Dhoni      670.0
# Name: Innings Runs Scored Num, dtype: float64

# %% [markdown]
# V Kohli has scores most runs(1120) in India.

# %%
sum.nlargest(5).plot.bar()
plt.title('Most Runs Scored In India',fontsize=20)
plt.ylabel('Runs Scored')
plt.show()

# %% [markdown]
# # HYPOTHESIS 3

# %% [markdown]
# An individual player(RG Sharma) has played most number of matches for a particular country(India).

# %% [markdown]
# Hypothesis is correct

# %%
#cretaing a dataframe which consists only players stats who palyed for India.
df3 = data_batting[(data_batting['Country'] == 'India')]
df3.head()
# Out:
#       Innings Player  Innings Runs Scored Num  Innings Minutes Batted  \
# 10794      RG Sharma                    118.0                    61.0
# 10795      RG Sharma                    111.0                    95.0
# 10796       KL Rahul                    110.0                    84.0
# 10797      RG Sharma                    106.0                    79.0
# 10798       KL Rahul                    101.0                     NaN
#
#        Innings Balls Faced  Innings Boundary Fours  Innings Boundary Sixes  \
# 10794                 43.0                    12.0                    10.0
# 10795                 61.0                     8.0                     7.0
# 10796                 51.0                    12.0                     5.0
# 10797                 66.0                    12.0                     5.0
# 10798                 54.0                    10.0                     5.0
#
#        Innings Batting Strike Rate Innings Number      Opposition      Ground  \
# ...

# %%
most_matches = df3['Innings Player'].value_counts()
#top 5 players who played most number of matches
most_matches.nlargest(5)
# Out:
# RG Sharma    108
# MS Dhoni      98
# V Kohli       82
# SK Raina      78
# S Dhawan      61
# Name: Innings Player, dtype: int64

# %% [markdown]
# RG Sharma has played most number of matches(108) for India

# %%
most_matches.nlargest(5).plot.bar()
plt.title('Most Matches played for India',fontsize=20)
plt.ylabel('Number of Innings Played')
plt.show()

# %% [markdown]
# # HYPOTHESIS 4

# %% [markdown]
# G Maxwell has best strike rate in overall T20I matches.

# %% [markdown]
# Hypothesis is false

# %%
#average of palyer batting strike rate
avg = data_batting.groupby('Innings Player')['Innings Batting Strike Rate'].mean()

# %%
#Top 5 players who has best batting strike rate 
avg.nlargest(5)
# Out:
# Innings Player
# Mohammad Asif       325.0
# PM Nevill           266.0
# Mohammad Rafique    260.0
# Aamer Yamin         250.0
# D Paterson          250.0
# Name: Innings Batting Strike Rate, dtype: float64

# %%
avg.nlargest(5).plot.barh()
plt.title('Best Batting Strike rate overall',fontsize=20)
plt.xlabel('Strike Rate')
plt.show()

# %% [markdown]
# Mohammad Asif has best batting strike rate.

# %% [markdown]
# # HYPOTHESIS 5

# %% [markdown]
# A Finch has scored highest number of sixes in an innings.

# %% [markdown]
# Hypothesis is false

# %%
#top 5 values of column 'Innings Boundary Sixes'
data_batting.nlargest(5,['Innings Boundary Sixes'])
# Out:
#           Innings Player  Innings Runs Scored Num  Innings Minutes Batted  \
# 31211  Hazratullah Zazai                    162.0                     NaN
# 1288            AJ Finch                    156.0                    70.0
# 30496          HG Munsey                    127.0                     NaN
# 2663             RE Levi                    117.0                    67.0
# 7988             E Lewis                    125.0                     NaN
#
#        Innings Balls Faced  Innings Boundary Fours  Innings Boundary Sixes  \
# 31211                 62.0                    11.0                    16.0
# 1288                  63.0                    11.0                    14.0
# 30496                 56.0                     5.0                    14.0
# 2663                  51.0                     5.0                    13.0
# 7988                  62.0                     6.0                    12.0
#
#        Innings Batting Strike Rate Innings Number     Opposition  \
# ...

# %% [markdown]
# Hazratullah Zazai has scored most number of sixes(16) in an innings.
#
# AJ Finch(14) is next to him.

# %% [markdown]
# # Learned From Project

# %% [markdown]
# using missing no library
#
# manipulating and cleaning data
#
# using groupby, n.largest() function
